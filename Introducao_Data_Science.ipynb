# %% [markdown]
# # Analisando as notas de forma geral

# %%
import pandas as pd

notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas["nota"]
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas[["nota"]]
# Out:
#         nota
# 0        4.0
# 1        4.0
# 2        4.0
# 3        5.0
# 4        5.0
# ...      ...
# 100831   4.0
# 100832   5.0
# 100833   5.0
# 100834   5.0
# 100835   3.0
#
# [100836 rows x 1 columns]

# %%
notas["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas["nota"].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
notas["nota"].mean()
# Out:
# 3.501556983616962

# %%
notas.nota
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas.nota.plot()

# %%
notas.nota.plot(kind="hist") # histograma

# %%
print(notas.nota.mean())
print(notas.nota.median())
# Out:
# 3.501556983616962
# 3.5

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.nota)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Olhando os filmes

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]

# %%
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# # Analisando algumas notas específicas por filme

# %%
notas.query("filmeId == 1").nota.mean()
# Out:
# 3.9209302325581397

# %%
notas.groupby("filmeId")

# %%
notas.groupby("filmeId").mean()
# Out:
#           usuarioId      nota       momento
# filmeId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
medias_por_filme = notas.groupby("filmeId").mean()["nota"]
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind="hist")

# %%
sns.boxplot(medias_por_filme)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 8))
sns.boxplot(y = medias_por_filme)

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.distplot(medias_por_filme)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(medias_por_filme, bins=10)

# %%
import matplotlib.pyplot as plt

plt.hist(medias_por_filme)
plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %%
tmdb = pd.read_csv("tmdb_5000_movies.csv")

# %%
tmdb.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
tmdb.original_language.unique() # categorica nominal
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb.query("original_language == 'en'").title
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4797                                      Cavite
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: title, Length: 4505, dtype: object

# %%
tmdb.original_language
# Out:
# 0       en
# 1       en
# 2       en
# 3       en
# 4       en
#         ..
# 4798    es
# 4799    en
# 4800    en
# 4801    en
# 4802    en
# Name: original_language, Length: 4803, dtype: object

# %%
tmdb.original_language.value_counts()
# Out:
# en    4505
# fr      70
# es      32
# de      27
# zh      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# id       2
# ar       2
# ro       2
# cs       2
# sl       1
# el       1
# tr       1
# nb       1
# xx       1
# is       1
# te       1
# pl       1
# ps       1
# vi       1
# af       1
# no       1
# ky       1
# hu       1
# Name: original_language, dtype: int64

# %%
tmdb.original_language.value_counts().to_frame()
# Out:
#     original_language
# en               4505
# fr                 70
# es                 32
# de                 27
# zh                 27
# hi                 19
# ja                 16
# it                 14
# cn                 12
# ko                 11
# ru                 11
# pt                  9
# da                  7
# sv                  5
# nl                  4
# fa                  4
# th                  3
# he                  3
# ta                  2
# id                  2
# ar                  2
# ro                  2
# cs                  2
# sl                  1
# el                  1
# tr                  1
# nb                  1
# xx                  1
# is                  1
# te                  1
# pl                  1
# ps                  1
# vi                  1
# af                  1
# no                  1
# ky                  1
# hu                  1

# %%
contagem_de_linguas = tmdb.original_language.value_counts().to_frame().reset_index()
contagem_de_linguas.columns = ["original_language", "total"]
contagem_de_linguas.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                de     27
# 4                zh     27

# %%
sns.barplot(x = "original_language", y = "total", data = contagem_de_linguas)

# %%
sns.catplot(x = "original_language", kind = "count" , data = tmdb)

# %%
plt.pie(contagem_de_linguas.total, labels = contagem_de_linguas.original_language)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdeb9ccbd30>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cda2b0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cda7b8>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cdacc0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9ce4208>,
#   <matplotlib.patches.Wedge at 0x7fdeb9ce4710>,
#   <matplotlib.patches.Wedge at 0x7fdeb9ce4c18>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cee160>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cee668>,
#   <matplotlib.patches.Wedge at 0x7fdeb9ceeb70>,
#   <matplotlib.patches.Wedge at 0x7fdeb9d20e80>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c78588>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c78a90>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c78f98>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c844e0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c849e8>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c84ef0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c91438>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c91940>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c91e48>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c9b390>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c9b898>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c9bda0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9ca52e8>,
#   <matplotlib.patches.Wedge at 0x7fdeb9ca57f0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9ca5cf8>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cb2240>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cb2748>,
#   <matplotlib.patches.Wedge at 0x7fdeb9cb2c50>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c3c198>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c3c6a0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c3cba8>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c490f0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c495f8>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c49b00>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c49fd0>,
#   <matplotlib.patches.Wedge at 0x7fdeb9c53550>],
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'de'),
#   Text(1.0773191105706255, -0.22222406260195313, 'zh'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ko'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ru'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
#   Text(1.0992355702663055, -0.04100196411527794, 'th'),
#   Text(1.0993880184234357, -0.03668766750546649, 'he'),
#   Text(1.0995021239019234, -0.033091985965784415, 'ta'),
#   Text(1.099584941078101, -0.03021518416739545, 'id'),
#   Text(1.0996602312343366, -0.027338175536150495, 'ar'),
#   Text(1.099727993855245, -0.024460979766119193, 'ro'),
#   Text(1.0997882284769684, -0.02158361655264929, 'cs'),
#   Text(1.0998284639438185, -0.01942549610642471, 'sl'),
#   Text(1.0998529348820232, -0.01798670707495573, 'el'),
#   Text(1.0998755236058106, -0.01654788726224571, 'tr'),
#   Text(1.0998962300765243, -0.01510903913059323, 'nb'),
#   Text(1.0999150542587282, -0.013670165142345335, 'xx'),
#   Text(1.0999319961202083, -0.012231267759896247, 'is'),
#   Text(1.0999470556319713, -0.01079234944567632, 'te'),
#   Text(1.099960232768245, -0.00935341266215563, 'pl'),
#   Text(1.0999715275064792, -0.007914459871831963, 'ps'),
#   Text(1.0999809398273452, -0.006475493537234394, 'vi'),
#   Text(1.0999884697147349, -0.005036516120911278, 'af'),
#   Text(1.0999941171557621, -0.0035975300854338356, 'no'),
#   Text(1.0999978821407626, -0.0021585378933851127, 'ky'),
#   Text(1.0999997646632929, -0.0007195420073586872, 'hu')])

# %%
total_por_lingua = tmdb.original_language.value_counts()
total_por_lingua
# Out:
# en    4505
# fr      70
# es      32
# de      27
# zh      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# id       2
# ar       2
# ro       2
# cs       2
# sl       1
# el       1
# tr       1
# nb       1
# xx       1
# is       1
# te       1
# pl       1
# ps       1
# vi       1
# af       1
# no       1
# ky       1
# hu       1
# Name: original_language, dtype: int64

# %%
total_de_ingles = total_por_lingua.loc['en']
total_de_ingles
# Out:
# 4505

# %%
total_geral = total_por_lingua.sum()
total_resto = total_geral - total_de_ingles

total_resto
# Out:
# 298

# %%
dados = {
    'lingua': ["inglês", "outros"],
    'total': [total_de_ingles, total_resto]
}

dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  inglês   4505
# 1  outros    298

# %%
sns.barplot(x = "lingua", y = "total", data = dados)

# %%
plt.pie(dados.total, labels = dados.lingua)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdeb9b92240>,
#   <matplotlib.patches.Wedge at 0x7fdeb9b92780>],
#  [Text(-1.0791697536499925, 0.2130554923183512, 'inglês'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
 tmdb.query("original_language != 'en'")
# Out:
#         budget  ... vote_count
# 97    15000000  ...        143
# 235   97250400  ...        471
# 317   94000000  ...        187
# 474          0  ...         47
# 492    8000000  ...          9
# ...        ...  ...        ...
# 4739         0  ...          1
# 4751         0  ...          2
# 4790         0  ...         17
# 4792     20000  ...         63
# 4798    220000  ...        238
#
# [298 rows x 20 columns]

# %%
total_por_lingua_resto = tmdb.query("original_language != 'en'").original_language.value_counts()
total_por_lingua_resto
# Out:
# fr    70
# es    32
# de    27
# zh    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# fa     4
# nl     4
# th     3
# he     3
# cs     2
# ta     2
# id     2
# ro     2
# ar     2
# hu     1
# te     1
# pl     1
# ky     1
# el     1
# ps     1
# xx     1
# af     1
# tr     1
# vi     1
# is     1
# sl     1
# nb     1
# no     1
# Name: original_language, dtype: int64

# %%
filmes_nao_ingles = tmdb.query("original_language != 'en'")
filmes_nao_ingles
# Out:
#         budget  ... vote_count
# 97    15000000  ...        143
# 235   97250400  ...        471
# 317   94000000  ...        187
# 474          0  ...         47
# 492    8000000  ...          9
# ...        ...  ...        ...
# 4739         0  ...          1
# 4751         0  ...          2
# 4790         0  ...         17
# 4792     20000  ...         63
# 4798    220000  ...        238
#
# [298 rows x 20 columns]

# %%
sns.catplot(x = "original_language", kind = "count",
            data = filmes_nao_ingles, aspect = 2, 
            order = total_por_lingua_resto.index)

# %%
sns.catplot(x = "original_language", kind = "count",
            data = filmes_nao_ingles, aspect = 2, 
            order = total_por_lingua_resto.index, 
            palette = "mako")

# %% [markdown]
# # Revisando o papel da média, mediana, medidas de tendência central, dispersão, desvio padrão, box plot, histograma

# %%
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
filmes.head(2)
# Out:
#    filmeId            titulo                                      generos
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas_toy_story = notas.query("filmeId == 1")
notas_jumanji = notas.query("filmeId == 2")
print(len(notas_toy_story), len(notas_jumanji))
# Out:
# 215 110

# %%
print("Nota média Toy Story: " + str(notas_toy_story.nota.mean()))
# Out:
# Nota média Toy Story: 3.9209302325581397

# %%
print("Nota média Jumanji: " + str(notas_jumanji.nota.mean()))
# Out:
# Nota média Jumanji: 3.4318181818181817

# %%
sns.boxplot(notas_toy_stort.nota)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(notas_jumanji.nota)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.boxplot([notas_toy_story.nota, notas_jumanji.nota])
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# {'boxes': [<matplotlib.lines.Line2D at 0x7fdeb92e5908>,
#   <matplotlib.lines.Line2D at 0x7fdeb9388a58>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fdeb92f5390>,
#   <matplotlib.lines.Line2D at 0x7fdeb92f5710>,
#   <matplotlib.lines.Line2D at 0x7fdeb927dbe0>,
#   <matplotlib.lines.Line2D at 0x7fdeb927df28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fdeb92f5e10>,
#   <matplotlib.lines.Line2D at 0x7fdeb928b5f8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fdeb92f5a90>,
#   <matplotlib.lines.Line2D at 0x7fdeb928b2b0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fdeb92e5c18>,
#   <matplotlib.lines.Line2D at 0x7fdeb92e5fd0>,
#   <matplotlib.lines.Line2D at 0x7fdeb927d4e0>,
#   <matplotlib.lines.Line2D at 0x7fdeb927d860>]}

# %%
sns.boxplot(x = "filmeId", y = "nota", data = notas.query("filmeId in [1,2]"))

# %%
notas_jumanji.nota.std()
# Out:
# 0.8817134921476455
